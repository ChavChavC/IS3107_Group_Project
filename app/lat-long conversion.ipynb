# %%
import pandas as pd

data = pd.read_csv('./data/booking with latlong.csv')

# %%
data
# Out:
#                                              hotel_name  \
# 0           Free Heated Pool Pool Table 15min To Disney
# 1     Florida Retreat with Patio, Near Beaches and B...
# 2                            6-A Diamond in Yonkers, NY
# 3     Charming Alabama Retreat with Patio and Pool A...
# 4                       Las Vegas Fun in the Sun, Strip
# ...                                                 ...
# 6082  7BDM Prvt Pool Villa - Gated Resort 10min to D...
# 6083       (B) Casa Azul. Minutes from the Beach & Mall
# 6084                         Alberta Arts Craftsman ADU
# 6085                      The Roscoe Village Guesthouse
# 6086  Petite Manufactured unit with Large Queen Bed ...
#
#                                       lat/long  \
# 0     [28.296833009597307, -81.46877996691912]
# 1                    [30.3436489, -81.4134168]
# 2      [40.94435686755196, -73.88587006083031]
# 3                      [34.632602, -86.484392]
# 4       [36.08654600851543, -115.078482010904]
# ...

# %%
data['lat/long'] = data['lat/long'].apply(eval)
data[['Latitude', 'Longitude']] = pd.DataFrame(data['lat/long'].tolist(), columns=['Latitude', 'Longitude'])

# %%
data.to_csv('./data/split_latlong.csv', index=False)
